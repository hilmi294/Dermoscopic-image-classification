# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd /content/drive/MyDrive/Dermoscopic_Image_Clasification/
# Out:
# /content/drive/MyDrive/Dermoscopic_Image_Clasification

# %%
# %tensorflow_version 1.x
# Out:
# TensorFlow 1.x selected.

# %%
import tensorflow
print(tensorflow.__version__)
# Out:
# 1.15.2

# %% [markdown]
# Data Preprocessing

# %%
import cv2,os
data_path='/content/drive/MyDrive/Dermoscopic_Image_Clasification/Dataset/'
categories=os.listdir(data_path)
labels=[i for i in range(len(categories))]

label_dict=dict(zip(categories,labels)) #empty dictionary
print(label_dict)
print(categories)
print(labels)
# Out:
# {'Melanoma': 0, 'Nevus': 1}
# ['Melanoma', 'Nevus']
# [0, 1]

# %%
img_size=100
data=[]
target=[]

for category in categories:
    folder_path=os.path.join(data_path,category)
    img_names=os.listdir(folder_path)
        
    for img_name in img_names:
        img_path=os.path.join(folder_path,img_name)
        img=cv2.imread(img_path)

        try:  
            resized=cv2.resize(img,(img_size,img_size))
            #resizing the image  into 100x100, since we need a fixed common size for all the images in the dataset
            data.append(resized)
            target.append(label_dict[category])
            #appending the image and the label(categorized) into the list (dataset)
        except Exception as e:
            print('Exception:',e)
            #if any exception rasied, the exception will be printed here. And pass to the next image

# %% [markdown]
# Declare and assign catagorical lables

# %%
import numpy as np
data=np.array(data)/255.0
data=np.reshape(data,(data.shape[0],img_size,img_size,3))
target=np.array(target)
from keras.utils import np_utils
new_target=np_utils.to_categorical(target)
# Out:
# Using TensorFlow backend.

# %%
new_target.shape
# Out:
# (12, 2)

# %% [markdown]
# CNN Model

# %%
data.shape
# Out:
# (12, 100, 100, 3)

# %%
data.shape[1:]
# Out:
# (100, 100, 3)

# %%
from keras.models import Sequential
from keras.layers import Dense,Activation,Flatten,Dropout
from keras.layers import Conv2D,MaxPooling2D
from keras.callbacks import ModelCheckpoint

model=Sequential()

model.add(Conv2D(200,(3,3),input_shape=data.shape[1:]))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
#The first CNN layer followed by Relu and MaxPooling layers

model.add(Conv2D(100,(3,3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
#The second convolution layer followed by Relu and MaxPooling layers

model.add(Flatten())
model.add(Dropout(0.5))
#Flatten layer to stack the output convolutions from second convolution layer
model.add(Dense(50,activation='relu'))
#Dense layer of 64 neurons
model.add(Dense(2,activation='softmax'))
#The Final layer with two outputs for two categories

model.compile(loss='categorical_crossentropy',optimizer='adam',metrics=['accuracy'])
# Out:
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.7/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.7/keras/backend/tensorflow_backend.py:4070: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 98, 98, 200)       5600
# _________________________________________________________________
# activation_1 (Activation)    (None, 98, 98, 200)       0
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 49, 49, 200)       0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 47, 47, 100)       180100
# _________________________________________________________________
# activation_2 (Activation)    (None, 47, 47, 100)       0
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 23, 23, 100)       0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 52900)             0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 52900)             0
# _________________________________________________________________
# dense_1 (Dense)              (None, 50)                2645050
# _________________________________________________________________
# dense_2 (Dense)              (None, 2)                 102
# =================================================================
# Total params: 2,830,852
# Trainable params: 2,830,852
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Splitting data into traning and testing

# %%
from sklearn.model_selection import train_test_split
train_data,test_data,train_target,test_target=train_test_split(data,new_target,test_size=0.1)

# %%
train_data.shape
# Out:
# (10, 100, 100, 3)

# %%
train_target.shape
# Out:
# (10, 2)

# %%
#checkpoint = ModelCheckpoint('model-{epoch:03d}.model',monitor='val_loss',verbose=0,save_best_only=True,mode='auto')
history=model.fit(train_data,train_target,epochs=200,validation_split=0.2)
# Out:
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.7/keras/backend/tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# Train on 8 samples, validate on 2 samples
# Epoch 1/200
# 8/8 [==============================] - 4s 503ms/step - loss: 0.6872 - accuracy: 0.6250 - val_loss: 1.6019 - val_accuracy: 0.5000
# Epoch 2/200
# 8/8 [==============================] - 0s 3ms/step - loss: 1.5519 - accuracy: 0.6250 - val_loss: 1.5617 - val_accuracy: 0.5000
# Epoch 3/200
# 8/8 [==============================] - 0s 3ms/step - loss: 1.4039 - accuracy: 0.3750 - val_loss: 0.8014 - val_accuracy: 0.5000
# Epoch 4/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.7670 - accuracy: 0.3750 - val_loss: 0.6770 - val_accuracy: 0.5000
# Epoch 5/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.6783 - accuracy: 0.6250 - val_loss: 0.6833 - val_accuracy: 0.5000
# Epoch 6/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.6880 - accuracy: 0.6250 - val_loss: 0.6861 - val_accuracy: 0.5000
# Epoch 7/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.6874 - accuracy: 0.6250 - val_loss: 0.6893 - val_accuracy: 0.5000
# Epoch 8/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.6751 - accuracy: 0.6250 - val_loss: 0.6940 - val_accuracy: 0.5000
# Epoch 9/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.6622 - accuracy: 0.6250 - val_loss: 0.6948 - val_accuracy: 0.5000
# Epoch 10/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.6721 - accuracy: 0.6250 - val_loss: 0.6849 - val_accuracy: 0.5000
# Epoch 11/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.6574 - accuracy: 0.5000 - val_loss: 0.6831 - val_accuracy: 0.5000
# Epoch 12/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.6006 - accuracy: 0.7500 - val_loss: 0.6865 - val_accuracy: 0.5000
# Epoch 13/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.5810 - accuracy: 0.6250 - val_loss: 0.6876 - val_accuracy: 0.5000
# Epoch 14/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.5231 - accuracy: 0.8750 - val_loss: 0.7015 - val_accuracy: 0.5000
# Epoch 15/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.4998 - accuracy: 0.7500 - val_loss: 0.6966 - val_accuracy: 0.5000
# Epoch 16/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.4599 - accuracy: 0.7500 - val_loss: 0.6303 - val_accuracy: 1.0000
# Epoch 17/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.3917 - accuracy: 0.8750 - val_loss: 0.6907 - val_accuracy: 0.5000
# Epoch 18/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.3513 - accuracy: 0.8750 - val_loss: 0.6117 - val_accuracy: 0.5000
# Epoch 19/200
# 8/8 [==============================] - 0s 4ms/step - loss: 0.3059 - accuracy: 1.0000 - val_loss: 0.4882 - val_accuracy: 1.0000
# Epoch 20/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.3166 - accuracy: 0.8750 - val_loss: 0.4687 - val_accuracy: 1.0000
# Epoch 21/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.2232 - accuracy: 0.8750 - val_loss: 0.6919 - val_accuracy: 0.5000
# Epoch 22/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.2157 - accuracy: 1.0000 - val_loss: 0.3958 - val_accuracy: 1.0000
# Epoch 23/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1279 - accuracy: 1.0000 - val_loss: 0.4133 - val_accuracy: 0.5000
# Epoch 24/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1388 - accuracy: 1.0000 - val_loss: 0.3817 - val_accuracy: 0.5000
# Epoch 25/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1236 - accuracy: 1.0000 - val_loss: 0.7557 - val_accuracy: 0.5000
# Epoch 26/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1230 - accuracy: 1.0000 - val_loss: 0.7114 - val_accuracy: 0.5000
# Epoch 27/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0977 - accuracy: 1.0000 - val_loss: 0.2678 - val_accuracy: 1.0000
# Epoch 28/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0969 - accuracy: 1.0000 - val_loss: 0.1149 - val_accuracy: 1.0000
# Epoch 29/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0289 - accuracy: 1.0000 - val_loss: 0.0899 - val_accuracy: 1.0000
# Epoch 30/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1313 - accuracy: 0.8750 - val_loss: 0.5118 - val_accuracy: 0.5000
# Epoch 31/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0558 - accuracy: 1.0000 - val_loss: 1.0444 - val_accuracy: 0.5000
# Epoch 32/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0469 - accuracy: 1.0000 - val_loss: 0.9317 - val_accuracy: 0.5000
# Epoch 33/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1167 - accuracy: 0.8750 - val_loss: 0.1385 - val_accuracy: 1.0000
# Epoch 34/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0725 - accuracy: 1.0000 - val_loss: 0.0800 - val_accuracy: 1.0000
# Epoch 35/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.6007 - accuracy: 0.8750 - val_loss: 0.5106 - val_accuracy: 0.5000
# Epoch 36/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1940 - accuracy: 0.8750 - val_loss: 0.3034 - val_accuracy: 1.0000
# Epoch 37/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0321 - accuracy: 1.0000 - val_loss: 0.1207 - val_accuracy: 1.0000
# Epoch 38/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0171 - accuracy: 1.0000 - val_loss: 0.0393 - val_accuracy: 1.0000
# Epoch 39/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0290 - accuracy: 1.0000 - val_loss: 0.0215 - val_accuracy: 1.0000
# Epoch 40/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0130 - accuracy: 1.0000 - val_loss: 0.0156 - val_accuracy: 1.0000
# Epoch 41/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0928 - accuracy: 1.0000 - val_loss: 0.0453 - val_accuracy: 1.0000
# Epoch 42/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0299 - accuracy: 1.0000 - val_loss: 0.1723 - val_accuracy: 1.0000
# Epoch 43/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.4925 - val_accuracy: 0.5000
# Epoch 44/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0941 - accuracy: 1.0000 - val_loss: 0.3953 - val_accuracy: 0.5000
# Epoch 45/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 0.3443 - val_accuracy: 1.0000
# Epoch 46/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.3243 - val_accuracy: 1.0000
# Epoch 47/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.2850 - val_accuracy: 1.0000
# Epoch 48/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.2649 - val_accuracy: 1.0000
# Epoch 49/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0034 - accuracy: 1.0000 - val_loss: 0.2747 - val_accuracy: 1.0000
# Epoch 50/200
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.2691 - val_accuracy: 1.0000
# Epoch 51/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0066 - accuracy: 1.0000 - val_loss: 0.2550 - val_accuracy: 1.0000
# Epoch 52/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0031 - accuracy: 1.0000 - val_loss: 0.2846 - val_accuracy: 1.0000
# Epoch 53/200
# 8/8 [==============================] - 0s 3ms/step - loss: 7.6785e-04 - accuracy: 1.0000 - val_loss: 0.3277 - val_accuracy: 1.0000
# Epoch 54/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0029 - accuracy: 1.0000 - val_loss: 0.3752 - val_accuracy: 0.5000
# Epoch 55/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.4065 - val_accuracy: 0.5000
# Epoch 56/200
# 8/8 [==============================] - 0s 3ms/step - loss: 9.3806e-05 - accuracy: 1.0000 - val_loss: 0.4398 - val_accuracy: 0.5000
# Epoch 57/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0097 - accuracy: 1.0000 - val_loss: 0.5287 - val_accuracy: 0.5000
# Epoch 58/200
# 8/8 [==============================] - 0s 3ms/step - loss: 4.5299e-04 - accuracy: 1.0000 - val_loss: 0.6192 - val_accuracy: 0.5000
# Epoch 59/200
# 8/8 [==============================] - 0s 3ms/step - loss: 9.6195e-04 - accuracy: 1.0000 - val_loss: 0.6706 - val_accuracy: 0.5000
# Epoch 60/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0190 - accuracy: 1.0000 - val_loss: 0.2560 - val_accuracy: 1.0000
# Epoch 61/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.0942 - val_accuracy: 1.0000
# Epoch 62/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0046 - accuracy: 1.0000 - val_loss: 0.0328 - val_accuracy: 1.0000
# Epoch 63/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0093 - accuracy: 1.0000 - val_loss: 0.0212 - val_accuracy: 1.0000
# Epoch 64/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.0164 - val_accuracy: 1.0000
# Epoch 65/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0133 - accuracy: 1.0000 - val_loss: 0.0225 - val_accuracy: 1.0000
# Epoch 66/200
# 8/8 [==============================] - 0s 3ms/step - loss: 2.6496e-04 - accuracy: 1.0000 - val_loss: 0.0315 - val_accuracy: 1.0000
# Epoch 67/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0041 - accuracy: 1.0000 - val_loss: 0.0615 - val_accuracy: 1.0000
# Epoch 68/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1025 - val_accuracy: 1.0000
# Epoch 69/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0026 - accuracy: 1.0000 - val_loss: 0.0977 - val_accuracy: 1.0000
# Epoch 70/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.0931 - val_accuracy: 1.0000
# Epoch 71/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0057 - accuracy: 1.0000 - val_loss: 0.1283 - val_accuracy: 1.0000
# Epoch 72/200
# 8/8 [==============================] - 0s 3ms/step - loss: 9.0707e-04 - accuracy: 1.0000 - val_loss: 0.1764 - val_accuracy: 1.0000
# Epoch 73/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0037 - accuracy: 1.0000 - val_loss: 0.2061 - val_accuracy: 1.0000
# Epoch 74/200
# 8/8 [==============================] - 0s 3ms/step - loss: 7.7432e-04 - accuracy: 1.0000 - val_loss: 0.2319 - val_accuracy: 1.0000
# Epoch 75/200
# 8/8 [==============================] - 0s 3ms/step - loss: 1.0562e-04 - accuracy: 1.0000 - val_loss: 0.2579 - val_accuracy: 1.0000
# Epoch 76/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.2654 - val_accuracy: 1.0000
# Epoch 77/200
# 8/8 [==============================] - 0s 3ms/step - loss: 3.3991e-04 - accuracy: 1.0000 - val_loss: 0.2756 - val_accuracy: 1.0000
# Epoch 78/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0027 - accuracy: 1.0000 - val_loss: 0.2930 - val_accuracy: 1.0000
# Epoch 79/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.2749 - val_accuracy: 1.0000
# Epoch 80/200
# 8/8 [==============================] - 0s 3ms/step - loss: 2.0576e-04 - accuracy: 1.0000 - val_loss: 0.2599 - val_accuracy: 1.0000
# Epoch 81/200
# 8/8 [==============================] - 0s 3ms/step - loss: 8.0530e-04 - accuracy: 1.0000 - val_loss: 0.2350 - val_accuracy: 1.0000
# Epoch 82/200
# 8/8 [==============================] - 0s 3ms/step - loss: 6.4608e-04 - accuracy: 1.0000 - val_loss: 0.2077 - val_accuracy: 1.0000
# Epoch 83/200
# 8/8 [==============================] - 0s 3ms/step - loss: 6.7658e-04 - accuracy: 1.0000 - val_loss: 0.1786 - val_accuracy: 1.0000
# Epoch 84/200
# 8/8 [==============================] - 0s 3ms/step - loss: 9.0439e-05 - accuracy: 1.0000 - val_loss: 0.1559 - val_accuracy: 1.0000
# Epoch 85/200
# 8/8 [==============================] - 0s 3ms/step - loss: 7.1900e-04 - accuracy: 1.0000 - val_loss: 0.1451 - val_accuracy: 1.0000
# Epoch 86/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0060 - accuracy: 1.0000 - val_loss: 0.1891 - val_accuracy: 1.0000
# Epoch 87/200
# 8/8 [==============================] - 0s 3ms/step - loss: 9.8279e-04 - accuracy: 1.0000 - val_loss: 0.2272 - val_accuracy: 1.0000
# Epoch 88/200
# 8/8 [==============================] - 0s 4ms/step - loss: 1.1656e-04 - accuracy: 1.0000 - val_loss: 0.2668 - val_accuracy: 1.0000
# Epoch 89/200
# 8/8 [==============================] - 0s 3ms/step - loss: 4.9140e-05 - accuracy: 1.0000 - val_loss: 0.3076 - val_accuracy: 1.0000
# Epoch 90/200
# 8/8 [==============================] - 0s 3ms/step - loss: 6.1960e-04 - accuracy: 1.0000 - val_loss: 0.3402 - val_accuracy: 1.0000
# Epoch 91/200
# 8/8 [==============================] - 0s 3ms/step - loss: 2.1833e-04 - accuracy: 1.0000 - val_loss: 0.3693 - val_accuracy: 0.5000
# Epoch 92/200
# 8/8 [==============================] - 0s 3ms/step - loss: 2.2432e-04 - accuracy: 1.0000 - val_loss: 0.3933 - val_accuracy: 0.5000
# Epoch 93/200
# 8/8 [==============================] - 0s 3ms/step - loss: 9.4472e-06 - accuracy: 1.0000 - val_loss: 0.4155 - val_accuracy: 0.5000
# Epoch 94/200
# 8/8 [==============================] - 0s 3ms/step - loss: 5.9906e-05 - accuracy: 1.0000 - val_loss: 0.4342 - val_accuracy: 0.5000
# Epoch 95/200
# 8/8 [==============================] - 0s 4ms/step - loss: 1.5269e-04 - accuracy: 1.0000 - val_loss: 0.4475 - val_accuracy: 0.5000
# Epoch 96/200
# 8/8 [==============================] - 0s 3ms/step - loss: 2.5863e-04 - accuracy: 1.0000 - val_loss: 0.4461 - val_accuracy: 0.5000
# Epoch 97/200
# 8/8 [==============================] - 0s 3ms/step - loss: 3.2578e-04 - accuracy: 1.0000 - val_loss: 0.4245 - val_accuracy: 0.5000
# Epoch 98/200
# 8/8 [==============================] - 0s 3ms/step - loss: 2.1650e-05 - accuracy: 1.0000 - val_loss: 0.4022 - val_accuracy: 0.5000
# Epoch 99/200
# 8/8 [==============================] - 0s 3ms/step - loss: 4.0737e-05 - accuracy: 1.0000 - val_loss: 0.3793 - val_accuracy: 0.5000
# Epoch 100/200
# 8/8 [==============================] - 0s 3ms/step - loss: 1.8221e-04 - accuracy: 1.0000 - val_loss: 0.3490 - val_accuracy: 0.5000
# Epoch 101/200
# 8/8 [==============================] - 0s 3ms/step - loss: 2.4145e-04 - accuracy: 1.0000 - val_loss: 0.3136 - val_accuracy: 1.0000
# Epoch 102/200
# 8/8 [==============================] - 0s 3ms/step - loss: 3.4461e-04 - accuracy: 1.0000 - val_loss: 0.2625 - val_accuracy: 1.0000
# Epoch 103/200
# 8/8 [==============================] - 0s 3ms/step - loss: 2.4502e-04 - accuracy: 1.0000 - val_loss: 0.2174 - val_accuracy: 1.0000
# Epoch 104/200
# 8/8 [==============================] - 0s 3ms/step - loss: 3.0748e-04 - accuracy: 1.0000 - val_loss: 0.1886 - val_accuracy: 1.0000
# Epoch 105/200
# 8/8 [==============================] - 0s 3ms/step - loss: 6.4324e-05 - accuracy: 1.0000 - val_loss: 0.1644 - val_accuracy: 1.0000
# Epoch 106/200
# 8/8 [==============================] - 0s 3ms/step - loss: 3.4435e-05 - accuracy: 1.0000 - val_loss: 0.1432 - val_accuracy: 1.0000
# Epoch 107/200
# 8/8 [==============================] - 0s 3ms/step - loss: 4.9169e-05 - accuracy: 1.0000 - val_loss: 0.1276 - val_accuracy: 1.0000
# Epoch 108/200
# 8/8 [==============================] - 0s 3ms/step - loss: 5.3842e-04 - accuracy: 1.0000 - val_loss: 0.0877 - val_accuracy: 1.0000
# Epoch 109/200
# 8/8 [==============================] - 0s 3ms/step - loss: 2.8759e-06 - accuracy: 1.0000 - val_loss: 0.0604 - val_accuracy: 1.0000
# Epoch 110/200
# 8/8 [==============================] - 0s 3ms/step - loss: 9.9323e-05 - accuracy: 1.0000 - val_loss: 0.0433 - val_accuracy: 1.0000
# Epoch 111/200
# 8/8 [==============================] - 0s 3ms/step - loss: 3.3331e-05 - accuracy: 1.0000 - val_loss: 0.0307 - val_accuracy: 1.0000
# Epoch 112/200
# 8/8 [==============================] - 0s 3ms/step - loss: 4.9914e-04 - accuracy: 1.0000 - val_loss: 0.0334 - val_accuracy: 1.0000
# Epoch 113/200
# 8/8 [==============================] - 0s 3ms/step - loss: 1.5522e-04 - accuracy: 1.0000 - val_loss: 0.0389 - val_accuracy: 1.0000
# Epoch 114/200
# 8/8 [==============================] - 0s 3ms/step - loss: 2.1929e-04 - accuracy: 1.0000 - val_loss: 0.0367 - val_accuracy: 1.0000
# Epoch 115/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0118 - accuracy: 1.0000 - val_loss: 0.0046 - val_accuracy: 1.0000
# Epoch 116/200
# 8/8 [==============================] - 0s 3ms/step - loss: 8.7690e-04 - accuracy: 1.0000 - val_loss: 9.5473e-04 - val_accuracy: 1.0000
# Epoch 117/200
# 8/8 [==============================] - 0s 3ms/step - loss: 4.0308e-04 - accuracy: 1.0000 - val_loss: 3.7364e-04 - val_accuracy: 1.0000
# Epoch 118/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 6.4647e-04 - val_accuracy: 1.0000
# Epoch 119/200
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0051 - accuracy: 1.0000 - val_loss: 0.0067 - val_accuracy: 1.0000
# Epoch 120/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0127 - accuracy: 1.0000 - val_loss: 0.3581 - val_accuracy: 0.5000
# Epoch 121/200
# 8/8 [==============================] - 0s 3ms/step - loss: 1.4120e-04 - accuracy: 1.0000 - val_loss: 1.9779 - val_accuracy: 0.5000
# Epoch 122/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0070 - accuracy: 1.0000 - val_loss: 2.2006 - val_accuracy: 0.5000
# Epoch 123/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0042 - accuracy: 1.0000 - val_loss: 1.5472 - val_accuracy: 0.5000
# Epoch 124/200
# 8/8 [==============================] - 0s 3ms/step - loss: 4.8317e-04 - accuracy: 1.0000 - val_loss: 0.6369 - val_accuracy: 0.5000
# Epoch 125/200
# 8/8 [==============================] - 0s 3ms/step - loss: 3.7796e-04 - accuracy: 1.0000 - val_loss: 0.0542 - val_accuracy: 1.0000
# Epoch 126/200
# 8/8 [==============================] - 0s 3ms/step - loss: 1.3003e-04 - accuracy: 1.0000 - val_loss: 8.1544e-04 - val_accuracy: 1.0000
# Epoch 127/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0093 - accuracy: 1.0000 - val_loss: 0.0065 - val_accuracy: 1.0000
# Epoch 128/200
# 8/8 [==============================] - 0s 3ms/step - loss: 8.2057e-05 - accuracy: 1.0000 - val_loss: 0.0359 - val_accuracy: 1.0000
# Epoch 129/200
# 8/8 [==============================] - 0s 3ms/step - loss: 5.9902e-06 - accuracy: 1.0000 - val_loss: 0.1256 - val_accuracy: 1.0000
# Epoch 130/200
# 8/8 [==============================] - 0s 3ms/step - loss: 5.8710e-06 - accuracy: 1.0000 - val_loss: 0.2907 - val_accuracy: 1.0000
# Epoch 131/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0056 - accuracy: 1.0000 - val_loss: 0.1704 - val_accuracy: 1.0000
# Epoch 132/200
# 8/8 [==============================] - 0s 3ms/step - loss: 5.7837e-05 - accuracy: 1.0000 - val_loss: 0.1009 - val_accuracy: 1.0000
# Epoch 133/200
# 8/8 [==============================] - 0s 3ms/step - loss: 3.8487e-05 - accuracy: 1.0000 - val_loss: 0.0601 - val_accuracy: 1.0000
# Epoch 134/200
# 8/8 [==============================] - 0s 3ms/step - loss: 3.4442e-04 - accuracy: 1.0000 - val_loss: 0.0409 - val_accuracy: 1.0000
# Epoch 135/200
# 8/8 [==============================] - 0s 3ms/step - loss: 5.4949e-05 - accuracy: 1.0000 - val_loss: 0.0292 - val_accuracy: 1.0000
# Epoch 136/200
# 8/8 [==============================] - 0s 3ms/step - loss: 2.0488e-05 - accuracy: 1.0000 - val_loss: 0.0218 - val_accuracy: 1.0000
# Epoch 137/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0053 - accuracy: 1.0000 - val_loss: 0.0419 - val_accuracy: 1.0000
# Epoch 138/200
# 8/8 [==============================] - 0s 3ms/step - loss: 1.6798e-04 - accuracy: 1.0000 - val_loss: 0.0711 - val_accuracy: 1.0000
# Epoch 139/200
# 8/8 [==============================] - 0s 3ms/step - loss: 1.5145e-04 - accuracy: 1.0000 - val_loss: 0.1067 - val_accuracy: 1.0000
# Epoch 140/200
# 8/8 [==============================] - 0s 3ms/step - loss: 5.9438e-04 - accuracy: 1.0000 - val_loss: 0.1477 - val_accuracy: 1.0000
# Epoch 141/200
# 8/8 [==============================] - 0s 3ms/step - loss: 4.4107e-06 - accuracy: 1.0000 - val_loss: 0.1829 - val_accuracy: 1.0000
# Epoch 142/200
# 8/8 [==============================] - 0s 3ms/step - loss: 3.0977e-05 - accuracy: 1.0000 - val_loss: 0.2181 - val_accuracy: 1.0000
# Epoch 143/200
# 8/8 [==============================] - 0s 3ms/step - loss: 1.7866e-05 - accuracy: 1.0000 - val_loss: 0.2530 - val_accuracy: 1.0000
# Epoch 144/200
# 8/8 [==============================] - 0s 3ms/step - loss: 7.7336e-06 - accuracy: 1.0000 - val_loss: 0.2882 - val_accuracy: 1.0000
# Epoch 145/200
# 8/8 [==============================] - 0s 3ms/step - loss: 6.1531e-05 - accuracy: 1.0000 - val_loss: 0.3242 - val_accuracy: 1.0000
# Epoch 146/200
# 8/8 [==============================] - 0s 3ms/step - loss: 3.9488e-06 - accuracy: 1.0000 - val_loss: 0.3595 - val_accuracy: 0.5000
# Epoch 147/200
# 8/8 [==============================] - 0s 3ms/step - loss: 3.1528e-05 - accuracy: 1.0000 - val_loss: 0.3945 - val_accuracy: 0.5000
# Epoch 148/200
# 8/8 [==============================] - 0s 3ms/step - loss: 2.3236e-04 - accuracy: 1.0000 - val_loss: 0.4334 - val_accuracy: 0.5000
# Epoch 149/200
# 8/8 [==============================] - 0s 3ms/step - loss: 3.4539e-05 - accuracy: 1.0000 - val_loss: 0.4695 - val_accuracy: 0.5000
# Epoch 150/200
# 8/8 [==============================] - 0s 3ms/step - loss: 7.5337e-04 - accuracy: 1.0000 - val_loss: 0.4660 - val_accuracy: 0.5000
# Epoch 151/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.4164 - val_accuracy: 0.5000
# Epoch 152/200
# 8/8 [==============================] - 0s 3ms/step - loss: 1.7773e-04 - accuracy: 1.0000 - val_loss: 0.3683 - val_accuracy: 0.5000
# Epoch 153/200
# 8/8 [==============================] - 0s 3ms/step - loss: 9.7635e-05 - accuracy: 1.0000 - val_loss: 0.3257 - val_accuracy: 1.0000
# Epoch 154/200
# 8/8 [==============================] - 0s 3ms/step - loss: 4.1791e-04 - accuracy: 1.0000 - val_loss: 0.2780 - val_accuracy: 1.0000
# Epoch 155/200
# 8/8 [==============================] - 0s 4ms/step - loss: 1.8790e-05 - accuracy: 1.0000 - val_loss: 0.2393 - val_accuracy: 1.0000
# Epoch 156/200
# 8/8 [==============================] - 0s 3ms/step - loss: 3.1292e-06 - accuracy: 1.0000 - val_loss: 0.2081 - val_accuracy: 1.0000
# Epoch 157/200
# 8/8 [==============================] - 0s 3ms/step - loss: 5.3043e-05 - accuracy: 1.0000 - val_loss: 0.1829 - val_accuracy: 1.0000
# Epoch 158/200
# 8/8 [==============================] - 0s 3ms/step - loss: 5.5137e-05 - accuracy: 1.0000 - val_loss: 0.1615 - val_accuracy: 1.0000
# Epoch 159/200
# 8/8 [==============================] - 0s 3ms/step - loss: 5.8163e-05 - accuracy: 1.0000 - val_loss: 0.1434 - val_accuracy: 1.0000
# Epoch 160/200
# 8/8 [==============================] - 0s 3ms/step - loss: 3.7145e-04 - accuracy: 1.0000 - val_loss: 0.1232 - val_accuracy: 1.0000
# Epoch 161/200
# 8/8 [==============================] - 0s 3ms/step - loss: 1.3813e-05 - accuracy: 1.0000 - val_loss: 0.1070 - val_accuracy: 1.0000
# Epoch 162/200
# 8/8 [==============================] - 0s 2ms/step - loss: 4.4121e-04 - accuracy: 1.0000 - val_loss: 0.0977 - val_accuracy: 1.0000
# Epoch 163/200
# 8/8 [==============================] - 0s 3ms/step - loss: 2.2932e-05 - accuracy: 1.0000 - val_loss: 0.0899 - val_accuracy: 1.0000
# Epoch 164/200
# 8/8 [==============================] - 0s 3ms/step - loss: 2.9355e-06 - accuracy: 1.0000 - val_loss: 0.0833 - val_accuracy: 1.0000
# Epoch 165/200
# 8/8 [==============================] - 0s 3ms/step - loss: 2.6433e-05 - accuracy: 1.0000 - val_loss: 0.0780 - val_accuracy: 1.0000
# Epoch 166/200
# 8/8 [==============================] - 0s 3ms/step - loss: 1.9192e-05 - accuracy: 1.0000 - val_loss: 0.0735 - val_accuracy: 1.0000
# Epoch 167/200
# 8/8 [==============================] - 0s 3ms/step - loss: 2.4824e-05 - accuracy: 1.0000 - val_loss: 0.0695 - val_accuracy: 1.0000
# Epoch 168/200
# 8/8 [==============================] - 0s 3ms/step - loss: 4.1585e-05 - accuracy: 1.0000 - val_loss: 0.0663 - val_accuracy: 1.0000
# Epoch 169/200
# 8/8 [==============================] - 0s 3ms/step - loss: 3.6458e-05 - accuracy: 1.0000 - val_loss: 0.0638 - val_accuracy: 1.0000
# Epoch 170/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0028 - accuracy: 1.0000 - val_loss: 0.0865 - val_accuracy: 1.0000
# Epoch 171/200
# 8/8 [==============================] - 0s 3ms/step - loss: 1.3858e-06 - accuracy: 1.0000 - val_loss: 0.1133 - val_accuracy: 1.0000
# Epoch 172/200
# 8/8 [==============================] - 0s 3ms/step - loss: 2.5688e-05 - accuracy: 1.0000 - val_loss: 0.1440 - val_accuracy: 1.0000
# Epoch 173/200
# 8/8 [==============================] - 0s 3ms/step - loss: 7.5200e-05 - accuracy: 1.0000 - val_loss: 0.1789 - val_accuracy: 1.0000
# Epoch 174/200
# 8/8 [==============================] - 0s 3ms/step - loss: 6.5682e-04 - accuracy: 1.0000 - val_loss: 0.2308 - val_accuracy: 1.0000
# Epoch 175/200
# 8/8 [==============================] - 0s 3ms/step - loss: 2.8027e-05 - accuracy: 1.0000 - val_loss: 0.2878 - val_accuracy: 1.0000
# Epoch 176/200
# 8/8 [==============================] - 0s 3ms/step - loss: 3.7428e-05 - accuracy: 1.0000 - val_loss: 0.3486 - val_accuracy: 0.5000
# Epoch 177/200
# 8/8 [==============================] - 0s 4ms/step - loss: 2.4804e-04 - accuracy: 1.0000 - val_loss: 0.4013 - val_accuracy: 0.5000
# Epoch 178/200
# 8/8 [==============================] - 0s 3ms/step - loss: 8.1251e-04 - accuracy: 1.0000 - val_loss: 0.4207 - val_accuracy: 0.5000
# Epoch 179/200
# 8/8 [==============================] - 0s 3ms/step - loss: 5.7369e-06 - accuracy: 1.0000 - val_loss: 0.4387 - val_accuracy: 0.5000
# Epoch 180/200
# 8/8 [==============================] - 0s 3ms/step - loss: 4.9318e-05 - accuracy: 1.0000 - val_loss: 0.4539 - val_accuracy: 0.5000
# Epoch 181/200
# 8/8 [==============================] - 0s 3ms/step - loss: 1.6435e-05 - accuracy: 1.0000 - val_loss: 0.4674 - val_accuracy: 0.5000
# Epoch 182/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0164 - accuracy: 1.0000 - val_loss: 0.0844 - val_accuracy: 1.0000
# Epoch 183/200
# 8/8 [==============================] - 0s 3ms/step - loss: 1.4155e-05 - accuracy: 1.0000 - val_loss: 0.0138 - val_accuracy: 1.0000
# Epoch 184/200
# 8/8 [==============================] - 0s 3ms/step - loss: 2.0756e-05 - accuracy: 1.0000 - val_loss: 0.0027 - val_accuracy: 1.0000
# Epoch 185/200
# 8/8 [==============================] - 0s 3ms/step - loss: 4.9452e-05 - accuracy: 1.0000 - val_loss: 6.4850e-04 - val_accuracy: 1.0000
# Epoch 186/200
# 8/8 [==============================] - 0s 3ms/step - loss: 5.7329e-05 - accuracy: 1.0000 - val_loss: 1.8528e-04 - val_accuracy: 1.0000
# Epoch 187/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 7.4262e-05 - val_accuracy: 1.0000
# Epoch 188/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0142 - accuracy: 1.0000 - val_loss: 9.8696e-05 - val_accuracy: 1.0000
# Epoch 189/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0791 - accuracy: 1.0000 - val_loss: 0.0169 - val_accuracy: 1.0000
# Epoch 190/200
# 8/8 [==============================] - 0s 3ms/step - loss: 1.1418e-04 - accuracy: 1.0000 - val_loss: 0.8290 - val_accuracy: 0.5000
# Epoch 191/200
# 8/8 [==============================] - 0s 3ms/step - loss: 4.9940e-05 - accuracy: 1.0000 - val_loss: 2.7843 - val_accuracy: 0.5000
# Epoch 192/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0083 - accuracy: 1.0000 - val_loss: 3.8708 - val_accuracy: 0.5000
# Epoch 193/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.4624 - accuracy: 0.7500 - val_loss: 0.0219 - val_accuracy: 1.0000
# Epoch 194/200
# 8/8 [==============================] - 0s 3ms/step - loss: 4.9225e-05 - accuracy: 1.0000 - val_loss: 1.0614e-04 - val_accuracy: 1.0000
# Epoch 195/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0136 - accuracy: 1.0000 - val_loss: 1.9490e-05 - val_accuracy: 1.0000
# Epoch 196/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1367 - accuracy: 1.0000 - val_loss: 1.4543e-05 - val_accuracy: 1.0000
# Epoch 197/200
# 8/8 [==============================] - 0s 4ms/step - loss: 0.5522 - accuracy: 0.8750 - val_loss: 0.0012 - val_accuracy: 1.0000
# Epoch 198/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0026 - accuracy: 1.0000 - val_loss: 0.1773 - val_accuracy: 1.0000
# Epoch 199/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0311 - accuracy: 1.0000 - val_loss: 1.0072 - val_accuracy: 0.5000
# Epoch 200/200
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 1.9728 - val_accuracy: 0.5000

# %%
model.save('model.h5')

# %%
from matplotlib import pyplot as plt

# %%
# plot the training loss and accuracy
N = 200
plt.style.use("ggplot")
plt.figure()
plt.plot(np.arange(0, N), history.history["loss"], label="train_loss")
plt.plot(np.arange(0, N), history.history["val_loss"], label="val_loss")
plt.plot(np.arange(0, N), history.history["accuracy"], label="train_acc")
plt.plot(np.arange(0, N), history.history["val_accuracy"], label="val_acc")
plt.title("Training Loss and Accuracy")
plt.xlabel("Epoch #")
plt.ylabel("Loss/Accuracy")
plt.legend(loc="center right")
plt.savefig("CNN_Model")
